# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/zheyue/Workspace/Projects/cs-e4780/2014-citibike-tripdata/2_February/201402-citibike-tripdata_1.csv')

# %%
df = pd.read_csv("/Users/zheyue/Workspace/Projects/cs-e4780/OpenCEP/scripts/demo_data.csv")

# %%
df
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           382  2014-01-31 23:57:00  2014-02-01 00:02:22                24
# 1           382  2014-02-01 00:05:00  2014-02-01 00:06:22                28
# 2           382  2014-02-01 00:06:23  2014-02-01 00:07:25               294
#
#     start station name  start station latitude  start station longitude  \
# 0  Washington Square E               40.730494               -73.995721
# 1  Washington Square E               40.730494               -73.995721
# 2  Washington Square E               40.730494               -73.995721
#
#    end station id          end station name  end station latitude  \
# 0              28  Stanton St & Chrystie St             40.722293
# 1             294  Stanton St & Chrystie St             40.722293
# 2             265  Stanton St & Chrystie St             40.722293
#
#    end station longitude  bikeid    usertype  birth year  gender
# ...

# %%
df.iloc[:1].to_csv('/Users/zheyue/Workspace/Projects/cs-e4780/2014-citibike-tripdata/2_February/201402-citibike-tripdata_2.csv', index=False)

# %%
df.iloc[:1]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           382  2014-02-01 00:00:00  2014-02-01 00:06:22               294
#
#     start station name  start station latitude  start station longitude  \
# 0  Washington Square E               40.730494               -73.995721
#
#    end station id          end station name  end station latitude  \
# 0             265  Stanton St & Chrystie St             40.722293
#
#    end station longitude  bikeid    usertype birth year  gender
# 0             -73.991475   21101  Subscriber       1991       1
